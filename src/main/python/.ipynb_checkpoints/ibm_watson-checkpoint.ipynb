# %%
from watson_developer_cloud import DiscoveryV1
import json

# %%
version="2018-03-05"
username="0013ab3f-5344-4203-91eb-1db0b958159f"
password = "tmqOrni8dUmu"
environment_id=  "system"
collection_id="news-en"

discovery = DiscoveryV1(
    version=version,
    username=username,
    password=password
)

# %%
query = 'baba'
filter = "language:(english|en),crawl_date>2018-03-08T12:00:00+0800,crawl_date<2018-05-08T12:00:00+0800"
aggregation = "term(host).term(enriched_text.sentiment.document.label)"

my_query = discovery.query(environment_id=environment_id, collection_id=collection_id, query='{query}', filter=filter, aggregations=[
    "term(host).term(enriched_text.sentiment.document.label)",
    "term(enriched_text.sentiment.document.label)"
  ])
print(json.dumps(my_query, indent=2))
# Out:
# {
#   "matching_results": 101319,
#   "results": [
#     {
#       "id": "MoLKAex0PWG73pjFX9_kY9nsz6iRFPUBKMsMYjf2eOsZbIdMdUhhv5u2Tk9KytqI",
#       "result_metadata": {
#         "score": 11.313161
#       },
#       "author": "Alexander Mont",
#       "enriched_title": {
#         "entities": [
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Google",
#             "relevance": 0.33,
#             "type": "Company",
#             "disambiguation": {
#               "subtype": [
#                 "AcademicInstitution",
#                 "AwardPresentingOrganization",
#                 "OperatingSystemDeveloper",
#                 "ProgrammingLanguageDeveloper",
#                 "SoftwareDeveloper",
#                 "VentureFundedCompany"
#               ],
#               "name": "Google",
#               "dbpedia_resource": "http://dbpedia.org/resource/Google"
#             }
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": 0,
#             "label": "neutral"
#           }
#         },
#         "semantic_roles": [
#           {
#             "subject": {
#               "text": "a query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": "How do you \"unpack\" a query that queries views in Google BigQuery?",
#             "object": {
#               "text": "views",
#               "keywords": [
#                 {
#                   "text": "views"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "query",
#                 "tense": "present"
#               },
#               "text": "queries",
#               "normalized": "query"
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Query language",
#             "relevance": 0.886784,
#             "dbpedia_resource": "http://dbpedia.org/resource/Query_language"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.998836,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.0465706,
#             "label": "/science/social science/history/genealogy"
#           },
#           {
#             "score": 0.0090022,
#             "label": "/technology and computing/internet technology/web search"
#           }
#         ],
#         "relations": [],
#         "keywords": [
#           {
#             "text": "Google BigQuery",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.930434
#           },
#           {
#             "text": "views",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.505
#           }
#         ]
#       },
#       "crawl_date": "2018-04-27T01:21:36Z",
#       "url": "https://stackoverflow.com/questions/50011383/how-do-you-unpack-a-query-that-queries-views-in-google-bigquery",
#       "host": "stackoverflow.com",
#       "text": "Suppose that I have a view in BigQuery, e.g. [views.myview] defined as follows: SELECT Id AS Id, MAX(Time) AS MostRecentTime FROM [dataset.mytable] GROUP BY Id And then another query that queries that view: SELECT * FROM [dataset.mytable] tbl JOIN [views.myview] view ON tbl.Time = mview.MostRecentTime Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly? (The underlying problem: I have a query which queries many different views, including several layers of views-querying-other-views, and I want to put this query in my application. I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the",
#       "main_image_url": "https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon@2.png?v=73d79a89bded",
#       "country": "US",
#       "source_type": "mainstream",
#       "language": "en",
#       "publication_date": "2018-04-27T01:22:00Z",
#       "enriched_text": {
#         "entities": [],
#         "sentiment": {
#           "document": {
#             "score": -0.53926,
#             "label": "negative"
#           }
#         },
#         "semantic_roles": [
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": "Suppose that I have a view in BigQuery, e.g. [views.myview] defined as follows: SELECT Id AS Id, MAX(Time) AS MostRecentTime FROM [dataset.mytable] GROUP BY Id",
#             "object": {
#               "text": "a view in BigQuery",
#               "keywords": [
#                 {
#                   "text": "view"
#                 },
#                 {
#                   "text": "BigQuery"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "have",
#                 "tense": "present"
#               },
#               "text": "have",
#               "normalized": "have"
#             }
#           },
#           {
#             "subject": {
#               "text": "Id",
#               "keywords": [
#                 {
#                   "text": "Id"
#                 }
#               ]
#             },
#             "sentence": "Suppose that I have a view in BigQuery, e.g. [views.myview] defined as follows: SELECT Id AS Id, MAX(Time) AS MostRecentTime FROM [dataset.mytable] GROUP BY Id",
#             "object": {
#               "text": "AS Id, MAX(Time) AS MostRecentTime FROM [dataset.mytable] GROUP BY Id",
#               "keywords": [
#                 {
#                   "text": "Id"
#                 },
#                 {
#                   "text": "MostRecentTime"
#                 },
#                 {
#                   "text": "GROUP"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "SELECT",
#                 "tense": "present"
#               },
#               "text": "SELECT",
#               "normalized": "SELECT"
#             }
#           },
#           {
#             "subject": {
#               "text": "another query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": " And then another query that queries that view: SELECT * FROM [dataset.mytable] tbl JOIN [views.myview] view ON tbl.Time = mview.MostRecentTime",
#             "object": {
#               "text": "that view: SELECT * FROM [dataset.mytable] tbl JOIN [views.myview] view ON tbl.Time = mview.MostRecentTime"
#             },
#             "action": {
#               "verb": {
#                 "text": "query",
#                 "tense": "present"
#               },
#               "text": "queries",
#               "normalized": "query"
#             }
#           },
#           {
#             "subject": {
#               "text": "a query where the [views.myview]",
#               "keywords": [
#                 {
#                   "text": "query"
#                 },
#                 {
#                   "text": "views.myview"
#                 }
#               ]
#             },
#             "sentence": " Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly?",
#             "action": {
#               "verb": {
#                 "text": "generate",
#                 "tense": "present"
#               },
#               "text": "to automatically generate",
#               "normalized": "to automatically generate"
#             }
#           },
#           {
#             "subject": {
#               "text": "the query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": " Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly?",
#             "object": {
#               "text": "it"
#             },
#             "action": {
#               "verb": {
#                 "text": "generate",
#                 "tense": "present"
#               },
#               "text": "generates",
#               "normalized": "generate"
#             }
#           },
#           {
#             "subject": {
#               "text": "you"
#             },
#             "sentence": " Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly?",
#             "object": {
#               "text": "the views",
#               "keywords": [
#                 {
#                   "text": "views"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "unpack",
#                 "tense": "present"
#               },
#               "text": "unpacking",
#               "normalized": "unpack"
#             }
#           },
#           {
#             "subject": {
#               "text": "you"
#             },
#             "sentence": " Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly?",
#             "object": {
#               "text": "just one query that queries tables directly",
#               "keywords": [
#                 {
#                   "text": "query"
#                 },
#                 {
#                   "text": "tables"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "have",
#                 "tense": "present"
#               },
#               "text": "have",
#               "normalized": "have"
#             }
#           },
#           {
#             "subject": {
#               "text": "just one query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": " Is there a way to automatically generate a query where the [views.myview] in the second query is replaced with the query that generates it - basically \"unpacking\" the views so you have just one query that queries tables directly?",
#             "object": {
#               "text": "tables directly",
#               "keywords": [
#                 {
#                   "text": "tables"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "query",
#                 "tense": "present"
#               },
#               "text": "queries",
#               "normalized": "query"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " (The underlying problem: I have a query which queries many different views, including several layers of views-querying-other-views, and I want to put this query in my application.",
#             "object": {
#               "text": "a query which queries many different views, including several layers of views-querying-other-views, and I want to put this query in my application",
#               "keywords": [
#                 {
#                   "text": "query"
#                 },
#                 {
#                   "text": "different views"
#                 },
#                 {
#                   "text": "layers"
#                 },
#                 {
#                   "text": "views-querying-other-views"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "have",
#                 "tense": "present"
#               },
#               "text": "have",
#               "normalized": "have"
#             }
#           },
#           {
#             "subject": {
#               "text": "a query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": " (The underlying problem: I have a query which queries many different views, including several layers of views-querying-other-views, and I want to put this query in my application.",
#             "object": {
#               "text": "many different views, including several layers of views-querying-other-views",
#               "keywords": [
#                 {
#                   "text": "layers"
#                 },
#                 {
#                   "text": "different views"
#                 },
#                 {
#                   "text": "views-querying-other-views"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "query",
#                 "tense": "present"
#               },
#               "text": "queries",
#               "normalized": "query"
#             }
#           },
#           {
#             "subject": {
#               "text": "several layers of views-querying-other-views",
#               "keywords": [
#                 {
#                   "text": "layers"
#                 },
#                 {
#                   "text": "views-querying-other-views"
#                 }
#               ]
#             },
#             "sentence": " (The underlying problem: I have a query which queries many different views, including several layers of views-querying-other-views, and I want to put this query in my application.",
#             "object": {
#               "text": "many different views",
#               "keywords": [
#                 {
#                   "text": "different views"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "include",
#                 "tense": "present"
#               },
#               "text": "including",
#               "normalized": "include"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the application.)",
#             "object": {
#               "text": "want"
#             },
#             "action": {
#               "verb": {
#                 "text": "do",
#                 "tense": "present",
#                 "negated": true
#               },
#               "text": "do",
#               "normalized": "do"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the application.)",
#             "object": {
#               "text": "a user to be able to mess",
#               "keywords": [
#                 {
#                   "text": "user"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "want",
#                 "tense": "future",
#                 "negated": true
#               },
#               "text": "want",
#               "normalized": "want"
#             }
#           },
#           {
#             "subject": {
#               "text": "a user",
#               "keywords": [
#                 {
#                   "text": "user"
#                 }
#               ]
#             },
#             "sentence": " I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the application.)",
#             "object": {
#               "text": "with the results of the query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 },
#                 {
#                   "text": "results"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "mess",
#                 "tense": "future"
#               },
#               "text": "to mess",
#               "normalized": "to mess"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the application.)",
#             "object": {
#               "text": "to put the whole query in a fixed form in the application",
#               "keywords": [
#                 {
#                   "text": "query"
#                 },
#                 {
#                   "text": "form"
#                 },
#                 {
#                   "text": "application"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "want",
#                 "tense": "present"
#               },
#               "text": "want",
#               "normalized": "want"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I don't want a user to be able to mess with the results of the query by changing the definition of one of the views, so I want to put the whole query in a fixed form in the application.)",
#             "object": {
#               "text": "the whole query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "put",
#                 "tense": "future"
#               },
#               "text": "want to put",
#               "normalized": "want to put"
#             }
#           }
#         ],
#         "concepts": [],
#         "categories": [
#           {
#             "score": 0.815595,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.445005,
#             "label": "/art and entertainment/movies and tv/romantic comedies"
#           },
#           {
#             "score": 0.077534,
#             "label": "/technology and computing/internet technology/web search"
#           }
#         ],
#         "relations": [],
#         "keywords": [
#           {
#             "text": "query",
#             "sentiment": {
#               "score": -0.439213,
#               "label": "negative"
#             },
#             "relevance": 0.997854
#           },
#           {
#             "text": "Id AS Id",
#             "sentiment": {
#               "score": -0.235964,
#               "label": "negative"
#             },
#             "relevance": 0.692433
#           },
#           {
#             "text": "underlying problem",
#             "sentiment": {
#               "score": -0.483312,
#               "label": "negative"
#             },
#             "relevance": 0.615982
#           },
#           {
#             "text": "different views",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.584614
#           },
#           {
#             "text": "application",
#             "sentiment": {
#               "score": -0.298092,
#               "label": "negative"
#             },
#             "relevance": 0.484744
#           },
#           {
#             "text": "MAX",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.453706
#           },
#           {
#             "text": "layers",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.453165
#           },
#           {
#             "text": "BigQuery",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.450078
#           },
#           {
#             "text": "Time",
#             "sentiment": {
#               "score": 0.335357,
#               "label": "positive"
#             },
#             "relevance": 0.449523
#           },
#           {
#             "text": "MostRecentTime",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.449425
#           },
#           {
#             "text": "GROUP",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.449262
#           },
#           {
#             "text": "tbl.Time",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.445102
#           },
#           {
#             "text": "mview.MostRecentTime",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.445042
#           },
#           {
#             "text": "definition",
#             "sentiment": {
#               "score": -0.580334,
#               "label": "negative"
#             },
#             "relevance": 0.444793
#           },
#           {
#             "text": "tables",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.442871
#           },
#           {
#             "text": "user",
#             "sentiment": {
#               "score": -0.580334,
#               "label": "negative"
#             },
#             "relevance": 0.442045
#           },
#           {
#             "text": "results",
#             "sentiment": {
#               "score": -0.580334,
#               "label": "negative"
#             },
#             "relevance": 0.441804
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "sha1": "9e59be6b44507c2226846af2ecaca94cc1a57697",
#         "filename": "1524792096867.zip-63f0fedb4e30f8595313533923faafc4.xml",
#         "file_type": "json"
#       },
#       "title": "How do you \"unpack\" a query that queries views in Google BigQuery?",
#       "forum_title": "Recent Questions - Stack Overflow"
#     },
#     {
#       "id": "79wK56S3uIQtcduAzgL29TIo7JlE6U7aqeOBt1pr_75yKV30dGEoY3Y4IxmyvTMd",
#       "result_metadata": {
#         "score": 11.298571
#       },
#       "author": "PurpleVermont",
#       "enriched_title": {
#         "entities": [
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Kibana Discover",
#             "relevance": 0.33,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": 0,
#             "label": "neutral"
#           }
#         },
#         "semantic_roles": [
#           {
#             "subject": {
#               "text": "Elastic Query DSL",
#               "keywords": [
#                 {
#                   "text": "Elastic Query DSL"
#                 }
#               ]
#             },
#             "sentence": "Using Elastic Query DSL in Kibana Discover to enable more_like_this etc",
#             "action": {
#               "verb": {
#                 "text": "Using",
#                 "tense": "present"
#               },
#               "text": "Using",
#               "normalized": "Using"
#             }
#           }
#         ],
#         "concepts": [],
#         "categories": [
#           {
#             "score": 0.80287,
#             "label": "/technology and computing/hardware/computer networking/router"
#           },
#           {
#             "score": 0.587688,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.059537,
#             "label": "/business and industrial"
#           }
#         ],
#         "relations": [],
#         "keywords": [
#           {
#             "text": "Elastic Query DSL",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.931449
#           },
#           {
#             "text": "Kibana Discover",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.554074
#           }
#         ]
#       },
#       "crawl_date": "2018-04-23T17:31:25Z",
#       "url": "https://stackoverflow.com/questions/49696892/using-elastic-query-dsl-in-kibana-discover-to-enable-more-like-this-etc",
#       "host": "stackoverflow.com",
#       "text": "up vote 0 down vote favorite The Kibana documentation says: When lucene is selected as your query language you can also submit queries using the Elasticsearch Query DSL. However, whenever I try to enter such a query in the Discover pane, I get a parse error. These are queries that work fine in the Dev Tools pane. For example, if I try even a simple query like this: {\"query\":{\"match_phrase\":{\"summary\":\"stochastic noise\"}}} I get the following error: Discover: [parsing_exception] no [query] registered for [query], with { line=1 & col=356 } Error: [parsing_exception] no [query] registered for [query], with { line=1 & col=356 } at respond (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:111:161556) at checkRespForFailure (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:111:160796) at http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:105:285566 at processQueue (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:132456) at http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:133349 at Scope.$digest (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:144239) at Scope.$apply (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:147018) at done (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:100026) at completeRequest (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:104697) at XMLHttpRequest.xhr.onload (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:105435) (I've removed my domain above and replaced with <mydomain> ) The above query works fine and returns results using cURL on",
#       "main_image_url": "https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon@2.png?v=73d79a89bded",
#       "country": "US",
#       "source_type": "mainstream",
#       "language": "en",
#       "publication_date": "2018-04-23T17:31:00Z",
#       "enriched_text": {
#         "entities": [],
#         "sentiment": {
#           "document": {
#             "score": 0.191015,
#             "label": "positive"
#           }
#         },
#         "semantic_roles": [
#           {
#             "subject": {
#               "text": "lucene",
#               "keywords": [
#                 {
#                   "text": "lucene"
#                 }
#               ]
#             },
#             "sentence": " When lucene is selected as your query language you can also submit queries using the Elasticsearch Query DSL.",
#             "object": {
#               "text": "selected as your query language",
#               "keywords": [
#                 {
#                   "text": "query language"
#                 }
#               ],
#               "entities": []
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "text": "is",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "you"
#             },
#             "sentence": " When lucene is selected as your query language you can also submit queries using the Elasticsearch Query DSL.",
#             "object": {
#               "text": "queries using the Elasticsearch Query DSL",
#               "keywords": [
#                 {
#                   "text": "Elasticsearch Query DSL"
#                 },
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "submit",
#                 "tense": "future"
#               },
#               "text": "can also submit",
#               "normalized": "can also submit"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " However, whenever I try to enter such a query in the Discover pane, I get a parse error.",
#             "object": {
#               "text": "to enter such a query in the Discover pane",
#               "keywords": [
#                 {
#                   "text": "Discover pane"
#                 },
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "try",
#                 "tense": "present"
#               },
#               "text": "try",
#               "normalized": "try"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " However, whenever I try to enter such a query in the Discover pane, I get a parse error.",
#             "object": {
#               "text": "such a query in the Discover pane",
#               "keywords": [
#                 {
#                   "text": "Discover pane"
#                 },
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "enter",
#                 "tense": "future"
#               },
#               "text": "try to enter",
#               "normalized": "try to enter"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " However, whenever I try to enter such a query in the Discover pane, I get a parse error.",
#             "object": {
#               "text": "a parse error",
#               "keywords": [
#                 {
#                   "text": "parse error"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "get",
#                 "tense": "present"
#               },
#               "text": "get",
#               "normalized": "get"
#             }
#           },
#           {
#             "subject": {
#               "text": "These"
#             },
#             "sentence": " These are queries that work fine in the Dev Tools pane.",
#             "object": {
#               "text": "queries that work fine in the Dev Tools pane",
#               "keywords": [
#                 {
#                   "text": "Dev Tools pane"
#                 },
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "text": "are",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "queries",
#               "keywords": [
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "sentence": " These are queries that work fine in the Dev Tools pane.",
#             "action": {
#               "verb": {
#                 "text": "work",
#                 "tense": "present"
#               },
#               "text": "work",
#               "normalized": "work"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " For example, if I try even a simple query like this: {\"query\":{\"match_phrase\":{\"summary\":\"stochastic noise\"}}}",
#             "object": {
#               "text": "even a simple query like this",
#               "keywords": [
#                 {
#                   "text": "simple query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "try",
#                 "tense": "present"
#               },
#               "text": "try",
#               "normalized": "try"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I get the following error: Discover: [parsing_exception] no [query] registered for [query], with { line=1 & col=356 } Error: [parsing_exception] no [query] registered for [query], with { line=1 & col=356 } at respond (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:111:161556) at checkRespForFailure (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:111:160796) at http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:105:285566 at processQueue (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:132456) at http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:133349 at Scope.$digest (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:144239) at Scope.$apply (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:147018) at done (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:100026) at completeRequest (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:104697) at XMLHttpRequest.xhr.onload (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:105435)",
#             "object": {
#               "text": "the following error",
#               "keywords": [
#                 {
#                   "text": "following error"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "get",
#                 "tense": "present"
#               },
#               "text": "get",
#               "normalized": "get"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " (I've removed my domain above and replaced with <mydomain> )",
#             "object": {
#               "text": "removed my domain above",
#               "keywords": [
#                 {
#                   "text": "domain"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "have",
#                 "tense": "present"
#               },
#               "text": "have",
#               "normalized": "have"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " (I've removed my domain above and replaced with <mydomain> )",
#             "object": {
#               "text": "my domain above",
#               "keywords": [
#                 {
#                   "text": "domain"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "remove",
#                 "tense": "past"
#               },
#               "text": "removed",
#               "normalized": "remove"
#             }
#           },
#           {
#             "subject": {
#               "text": "cURL",
#               "keywords": [
#                 {
#                   "text": "cURL"
#                 }
#               ]
#             },
#             "sentence": " The above query works fine and returns results using cURL on the command line, or using GET /_search { \"query\": { \"match_phrase\": { \"summary\": \"stochastic noise\" } } }",
#             "object": {
#               "text": "on the command line",
#               "keywords": [
#                 {
#                   "text": "command line"
#                 }
#               ],
#               "entities": []
#             },
#             "action": {
#               "verb": {
#                 "text": "use",
#                 "tense": "present"
#               },
#               "text": "using",
#               "normalized": "use"
#             }
#           },
#           {
#             "subject": {
#               "text": "query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "sentence": " The above query works fine and returns results using cURL on the command line, or using GET /_search { \"query\": { \"match_phrase\": { \"summary\": \"stochastic noise\" } } }",
#             "object": {
#               "text": "/_search",
#               "keywords": [
#                 {
#                   "text": "/_search"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "GET",
#                 "tense": "present"
#               },
#               "text": "GET",
#               "normalized": "GET"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I'm hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax.",
#             "object": {
#               "text": "hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax",
#               "keywords": [
#                 {
#                   "text": "straight lucene query"
#                 },
#                 {
#                   "text": "Query DSL"
#                 },
#                 {
#                   "text": "more_like_this query"
#                 },
#                 {
#                   "text": "Discover panel"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "text": "am",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I'm hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax.",
#             "object": {
#               "text": "to use the more_like_this query from the Discover panel",
#               "keywords": [
#                 {
#                   "text": "Discover panel"
#                 },
#                 {
#                   "text": "more_like_this query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "hope",
#                 "tense": "present"
#               },
#               "text": "hoping",
#               "normalized": "hope"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I'm hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax.",
#             "object": {
#               "text": "the more_like_this query",
#               "keywords": [
#                 {
#                   "text": "query"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "use",
#                 "tense": "future"
#               },
#               "text": "hoping to use",
#               "normalized": "hope to use"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I'm hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax.",
#             "object": {
#               "text": "to use the Query DSL",
#               "keywords": [
#                 {
#                   "text": "Query DSL"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "need",
#                 "tense": "future"
#               },
#               "text": "need",
#               "normalized": "need"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I'm hoping to use the more_like_this query from the Discover panel, so (I think) I will need to use the Query DSL and not just use the straight lucene query syntax.",
#             "object": {
#               "text": "the straight lucene query syntax",
#               "keywords": [
#                 {
#                   "text": "straight lucene query"
#                 },
#                 {
#                   "text": "syntax"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "use",
#                 "tense": "present",
#                 "negated": true
#               },
#               "text": "just use",
#               "normalized": "just use"
#             }
#           },
#           {
#             "subject": {
#               "text": "there"
#             },
#             "sentence": " But if there's a way to use the specialty queries like that using straight lucene (or kuery) that would be great.",
#             "object": {
#               "text": "a way to use the specialty queries like that using straight lucene (or kuery) that would be great",
#               "keywords": [
#                 {
#                   "text": "straight lucene"
#                 },
#                 {
#                   "text": "kuery"
#                 },
#                 {
#                   "text": "way"
#                 },
#                 {
#                   "text": "specialty"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "has",
#                 "tense": "present"
#               },
#               "text": "has",
#               "normalized": "has"
#             }
#           },
#           {
#             "subject": {
#               "text": "'s a way to use the specialty",
#               "keywords": [
#                 {
#                   "text": "way"
#                 },
#                 {
#                   "text": "specialty"
#                 }
#               ]
#             },
#             "sentence": " But if there's a way to use the specialty queries like that using straight lucene (or kuery) that would be great.",
#             "object": {
#               "text": "using straight lucene (or kuery) that would be great",
#               "keywords": [
#                 {
#                   "text": "straight lucene"
#                 },
#                 {
#                   "text": "kuery"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "query",
#                 "tense": "present"
#               },
#               "text": "queries",
#               "normalized": "query"
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Query language",
#             "relevance": 0.932431,
#             "dbpedia_resource": "http://dbpedia.org/resource/Query_language"
#           },
#           {
#             "text": "Panel",
#             "relevance": 0.642689,
#             "dbpedia_resource": "http://dbpedia.org/resource/Panel"
#           },
#           {
#             "text": "Following",
#             "relevance": 0.64064,
#             "dbpedia_resource": "http://dbpedia.org/resource/Following"
#           },
#           {
#             "text": "XPath",
#             "relevance": 0.586845,
#             "dbpedia_resource": "http://dbpedia.org/resource/XPath"
#           },
#           {
#             "text": "Christopher Nolan",
#             "relevance": 0.58268,
#             "dbpedia_resource": "http://dbpedia.org/resource/Christopher_Nolan"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.764316,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.394122,
#             "label": "/technology and computing/software"
#           },
#           {
#             "score": 0.22447,
#             "label": "/law, govt and politics/politics/elections/referendums"
#           }
#         ],
#         "relations": [
#           {
#             "type": "agentOf",
#             "sentence": "$apply (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:147018) at done (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:100026) at completeRequest (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:104697) at XMLHttpRequest.xhr.onload (http://<mydomain>:5601/bundles/vendors.bundle.js?v=16602:58:105435)  (I've removed my domain above and replaced with <mydomain> )  The above query works fine and returns results using cURL on the command line, or using GET /_search { \"query\": { \"match_phrase\": { \"summary\": \"stochastic noise\" } } }  In the Dev Tools console.",
#             "score": 0.418828,
#             "arguments": [
#               {
#                 "text": "my",
#                 "location": [
#                   1486,
#                   1488
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "your"
#                   }
#                 ]
#               },
#               {
#                 "text": "replaced",
#                 "location": [
#                   1506,
#                   1514
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventPersonnel",
#                     "text": "replaced"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "query",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.965022
#           },
#           {
#             "text": "Elasticsearch Query DSL",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.803302
#           },
#           {
#             "text": "straight lucene query",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.777742
#           },
#           {
#             "text": "query language",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.64654
#           },
#           {
#             "text": "more_like_this query",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.584914
#           },
#           {
#             "text": "query works",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.579786
#           },
#           {
#             "text": "Dev Tools pane",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.462238
#           },
#           {
#             "text": "stochastic noise",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.43715
#           },
#           {
#             "text": "Dev Tools console",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.388832
#           },
#           {
#             "text": "Discover pane",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.329848
#           },
#           {
#             "text": "parse error",
#             "sentiment": {
#               "score": -0.622609,
#               "label": "negative"
#             },
#             "relevance": 0.312179
#           },
#           {
#             "text": "following error",
#             "sentiment": {
#               "score": -0.417149,
#               "label": "negative"
#             },
# ...
#           },
#           {
#             "subject": {
#               "text": "myself"
#             },
#             "sentence": " However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "object": {
#               "text": "the same queries",
#               "keywords": [
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "declare",
#                 "tense": "present"
#               },
#               "text": "declaring",
#               "normalized": "declare"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "object": {
#               "text": "the same queries",
#               "keywords": [
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "call",
#                 "tense": "present"
#               },
#               "text": "calling",
#               "normalized": "call"
#             }
#           },
#           {
#             "subject": {
#               "text": "certain actions",
#               "keywords": [
#                 {
#                   "text": "certain actions"
#                 }
#               ]
#             },
#             "sentence": " However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "object": {
#               "text": "performed by the user (such as changing the date",
#               "keywords": [
#                 {
#                   "text": "user"
#                 },
#                 {
#                   "text": "date"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "text": "are",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "by the user (such as changing the date and loading the data from that date)",
#               "keywords": [
#                 {
#                   "text": "date"
#                 },
#                 {
#                   "text": "user"
#                 },
#                 {
#                   "text": "data"
#                 }
#               ]
#             },
#             "sentence": " However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "object": {
#               "text": "certain actions",
#               "keywords": [
#                 {
#                   "text": "certain actions"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "perform",
#                 "tense": "past"
#               },
#               "text": "are performed",
#               "normalized": "be perform"
#             }
#           },
#           {
#             "subject": {
#               "text": "certain actions",
#               "keywords": [
#                 {
#                   "text": "certain actions"
#                 }
#               ]
#             },
#             "sentence": " However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "object": {
#               "text": "the data",
#               "keywords": [
#                 {
#                   "text": "data"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "load",
#                 "tense": "present"
#               },
#               "text": "loading",
#               "normalized": "load"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " Thus, I am wondering if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor.",
#             "object": {
#               "text": "wondering if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor",
#               "keywords": [
#                 {
#                   "text": "Database Contract class"
#                 },
#                 {
#                   "text": "separate class"
#                 },
#                 {
#                   "text": "Cursor"
#                 },
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "text": "am",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " Thus, I am wondering if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor.",
#             "object": {
#               "text": "if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor",
#               "keywords": [
#                 {
#                   "text": "Database Contract class"
#                 },
#                 {
#                   "text": "separate class"
#                 },
#                 {
#                   "text": "Cursor"
#                 },
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "wonder",
#                 "tense": "present"
#               },
#               "text": "am wondering",
#               "normalized": "be wonder"
#             }
#           },
#           {
#             "subject": {
#               "text": "queries",
#               "keywords": [
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "sentence": " Thus, I am wondering if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor.",
#             "object": {
#               "text": "to be kept in a separate class (such as the Database Contract class?",
#               "keywords": [
#                 {
#                   "text": "Database Contract class"
#                 },
#                 {
#                   "text": "separate class"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "suppose",
#                 "tense": "past"
#               },
#               "text": "supposed",
#               "normalized": "suppose"
#             }
#           },
#           {
#             "subject": {
#               "text": "queries",
#               "keywords": [
#                 {
#                   "text": "queries"
#                 }
#               ]
#             },
#             "sentence": " Thus, I am wondering if queries are supposed to be kept in a separate class (such as the Database Contract class?) or possibly even in their own methods that return a Cursor.",
#             "object": {
#               "text": "kept in a separate class (such as the Database Contract class",
#               "keywords": [
#                 {
#                   "text": "Database Contract class"
#                 },
#                 {
#                   "text": "separate class"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "be",
#                 "tense": "future"
#               },
#               "text": "be",
#               "normalized": "be"
#             }
#           },
#           {
#             "subject": {
#               "text": "I"
#             },
#             "sentence": " I would imagine something along the lines of a method getTransactionsByDate(Date newDate) could be used.",
#             "object": {
#               "text": "something along the lines of a method getTransactionsByDate(Date newDate) could be used",
#               "keywords": [
#                 {
#                   "text": "method getTransactionsByDate"
#                 },
#                 {
#                   "text": "Date newDate"
#                 },
#                 {
#                   "text": "lines"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "imagine",
#                 "tense": "future"
#               },
#               "text": "would imagine",
#               "normalized": "would imagine"
#             }
#           },
#           {
#             "subject": {
#               "text": "there"
#             },
#             "sentence": " Is there an established pattern that I may not be aware of?",
#             "object": {
#               "text": "an established pattern that I may not be aware of",
#               "keywords": [
#                 {
#                   "text": "pattern"
#                 }
#               ]
#             },
#             "action": {
#               "verb": {
#                 "text": "Is",
#                 "tense": "present"
#               },
#               "text": "Is",
#               "normalized": "Is"
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Subroutine",
#             "relevance": 0.956039,
#             "dbpedia_resource": "http://dbpedia.org/resource/Subroutine"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.553826,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.446345,
#             "label": "/hobbies and interests/arts and crafts/crochet"
#           },
#           {
#             "score": 0.301222,
#             "label": "/law, govt and politics/politics/elections/referendums"
#           }
#         ],
#         "relations": [
#           {
#             "type": "agentOf",
#             "sentence": "up vote 0 down vote favorite  I have a small Android project, and I currently declare and call database (SQLite) queries in my Activity classes.",
#             "score": 0.808115,
#             "arguments": [
#               {
#                 "text": "I",
#                 "location": [
#                   66,
#                   67
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "myself"
#                   }
#                 ]
#               },
#               {
#                 "text": "declare",
#                 "location": [
#                   78,
#                   85
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "declare"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "However, the queries are somewhat verbose, and I find myself declaring and calling the same queries over and over after certain actions are performed by the user (such as changing the date and loading the data from that date).",
#             "score": 0.990427,
#             "arguments": [
#               {
#                 "text": "myself",
#                 "location": [
#                   199,
#                   205
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "myself"
#                   }
#                 ]
#               },
#               {
#                 "text": "declaring",
#                 "location": [
#                   206,
#                   215
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "declaring"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "small Android project",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.928736
#           },
#           {
#             "text": "Database Contract class",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.792502
#           },
#           {
#             "text": "queries",
#             "sentiment": {
#               "score": -0.34568,
#               "label": "negative"
#             },
#             "relevance": 0.755855
#           },
#           {
#             "text": "certain actions",
#             "sentiment": {
#               "score": -0.298946,
#               "label": "negative"
#             },
#             "relevance": 0.639805
#           },
#           {
#             "text": "Activity classes",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.618805
#           },
#           {
#             "text": "established pattern",
#             "sentiment": {
#               "score": -0.31462,
#               "label": "negative"
#             },
#             "relevance": 0.612679
#           },
#           {
#             "text": "separate class",
#             "sentiment": {
#               "score": -0.392413,
#               "label": "negative"
#             },
#             "relevance": 0.590854
#           },
#           {
#             "text": "method getTransactionsByDate",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.580153
#           },
#           {
#             "text": "Date newDate",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.553511
#           },
#           {
#             "text": "vote",
#             "sentiment": {
#               "score": 0.704316,
#               "label": "positive"
#             },
#             "relevance": 0.497711
#           },
#           {
#             "text": "SQLite",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.399951
#           },
#           {
#             "text": "Cursor",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.387735
#           },
#           {
#             "text": "user",
#             "sentiment": {
#               "score": -0.298946,
#               "label": "negative"
#             },
#             "relevance": 0.355558
#           },
#           {
#             "text": "methods",
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "relevance": 0.352502
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "sha1": "19758db2b019d8e263b148fd7f75c177fc94ce6c",
#         "filename": "1524316037675.zip-13bad7ed6e0b757d0b0574b8f49f26d4.xml",
#         "file_type": "json"
#       },
#       "title": "In Android, where should database queries be kept?",
#       "forum_title": "Recent Questions - Stack Overflow"
#     }
#   ]
# }
